# %%
# %pip install owslib
# Out:
# Collecting owslib
#   Downloading owslib-0.34.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting lxml (from owslib)
#   Downloading lxml-6.0.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from owslib) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from owslib) (6.0.2)
# Requirement already satisfied: requests in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from owslib) (2.32.4)
# Requirement already satisfied: six>=1.5 in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from python-dateutil->owslib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from requests->owslib) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from requests->owslib) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from requests->owslib) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/corentinpradier/Documents/Codes/cloud-project/venv/lib/python3.11/site-packages (from requests->owslib) (2025.7.14)
# Downloading owslib-0.34.1-py3-none-any.whl (240 kB)
# Downloading lxml-6.0.0-cp311-cp311-macosx_10_9_universal2.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 79.8 MB/s  0:00:00
# Installing collected packages: lxml, owslib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [owslib]2m1/2 [owslib]
# Successfully installed lxml-6.0.0 owslib-0.34.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from owslib.wms import WebMapService
from IPython.display import Image, display
import matplotlib.pyplot as plt

# %%
# Connect to GIBS WMS Service
wms = WebMapService('https://gibs.earthdata.nasa.gov/wms/epsg4326/best/wms.cgi?', version='1.1.1')

# Configure request for MODIS_Terra_CorrectedReflectance_TrueColor
img = wms.getmap(layers=['MODIS_Terra_CorrectedReflectance_TrueColor'],  # Layers
                 srs='epsg:4326',  # Map projection
                 bbox=(-180,-90,180,90),  # Bounds
                 size=(1200, 600),  # Image size
                 time='2021-09-21',  # Time of data
                 format='image/png',  # Image format
                 transparent=True)  # Nodata transparency

# %%
out = open('MODIS_Terra_CorrectedReflectance_TrueColor.png', 'wb')
out.write(img.read())
out.close()

# %%
Image('MODIS_Terra_CorrectedReflectance_TrueColor.png')
